# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('/Users/matanefron/Downloads/How is the World Feeling? - Raw Data.xlsx')
# Out:
#    Master User ID   Age  Gender ID  Gender  Sexual Identity ID  \
# 0               1  32.0        1.0    Male                 2.0
# 1               2  24.0        2.0  Female                 3.0
# 2               3  41.0        1.0    Male                 2.0
# 3               4  20.0        2.0  Female                 1.0
# 4               5  25.0        2.0  Female                 4.0
#
#   Sexual Identity  Relationship Status ID Relationship Status  Height  Weight  \
# 0             Gay                     1.0              Single   182.0     NaN
# 1        Bisexual                     2.0              Dating   167.0     NaN
# 2             Gay                     3.0             Engaged   185.0     NaN
# 3        Straight                     1.0              Single   168.0     NaN
# 4           Other                     6.0            Divorced   170.0     NaN
#
#              ...              Ethnicity  Employment Status ID  \
# ...

# %%
df.shape
# Out:
# (10144, 27)

# %%
df2=df
# Out:
#    Master User ID   Age  Gender ID  Gender  Sexual Identity ID  \
# 0               1  32.0        1.0    Male                 2.0
# 1               2  24.0        2.0  Female                 3.0
# 2               3  41.0        1.0    Male                 2.0
# 3               4  20.0        2.0  Female                 1.0
# 4               5  25.0        2.0  Female                 4.0
#
#   Sexual Identity  Relationship Status ID Relationship Status  Height  Weight  \
# 0             Gay                     1.0              Single   182.0     NaN
# 1        Bisexual                     2.0              Dating   167.0     NaN
# 2             Gay                     3.0             Engaged   185.0     NaN
# 3        Straight                     1.0              Single   168.0     NaN
# 4           Other                     6.0            Divorced   170.0     NaN
#
#              ...              Ethnicity  Employment Status ID  \
# ...

# %%
df_missing=df2.dropna()

# %%
df_missing.head()
# Out:
#       Master User ID   Age  Gender ID  Gender  Sexual Identity ID  \
# 22                24  21.0        1.0    Male                 1.0
# 24                26  40.0        1.0    Male                 1.0
# 980              989  64.0        2.0  Female                 1.0
# 1105            1114  19.0        1.0    Male                 1.0
# 1721            1774  23.0        2.0  Female                 1.0
#
#      Sexual Identity  Relationship Status ID    Relationship Status  Height  \
# 22          Straight                     1.0                 Single   181.0
# 24          Straight                     5.0  Married / Civil Union   182.0
# 980         Straight                     5.0  Married / Civil Union   165.0
# 1105        Straight                     1.0                 Single   176.0
# 1721        Straight                     4.0              Committed   167.0
#
#       Weight            ...                      Ethnicity  \
# ...

# %%
df_missing_2 = df_missing[['Age','Gender ID']].astype(int)

# %%
df_missing_2
# Out:
#        Age  Gender ID
# 22      21          1
# 24      40          1
# 980     64          2
# 1105    19          1
# 1721    23          2
# 1734    24          2
# 1739    27          1
# 1748    36          2
# 1754    47          2
# 1767    23          1
# 1917    37          1
# 1932    51          1
# 2086    22          1
# 2212    16          2
# 2216    27          2
# 2217    31          2
# 2220    33          2
# 2222    23          2
# 2226    26          1
# 2230    21          1
# 2231    26          1
# 2234    20          2
# 2236    23          1
# 2238    23          1
# 2242    16          1
# 2243    15          2
# 2244    18          2
# 2245    16          2
# 2247    25          2
# 2257    22          2
# ...    ...        ...
# 10050   26          1
# 10052   18          2
# 10053   46          2
# 10059   31          1
# 10061   44          1
# 10062   20          2
# 10064   37          2
# 10068   22          2
# 10072   99          2
# ...

# %%
import seaborn as sns

sns.heatmap(df.corr(method='pearson'))
